# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dffood=pd.read_csv('food_coded.csv')

# %% [markdown]
# Dropping Unuseful Columns:

# %%
d=dffood[['cook','eating_out','employment','ethnic_food','exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day']].copy()
d.dropna(axis=0,inplace=True)
d.head(7)
# Out:
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0   2.0           3         3.0            1       1.0          5     5.0
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 3   2.0           2         3.0            5       3.0          4     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
# 5   3.0           1         3.0            4       2.0          2     1.0
# 6   2.0           2         3.0            5       1.0          4     4.0
#
#    on_off_campus  pay_meal_out  sports  veggies_day
# 0            1.0             2     1.0            5
# 1            1.0             4     1.0            4
# 2            2.0             3     2.0            5
# 3            1.0             2     2.0            3
# 4            1.0             4     1.0            4
# 5            1.0             5     2.0            1
# ...

# %% [markdown]
# Visualising the Data:

# %%
ax= d.boxplot(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
# Out:
# [Text(1, 0, 'cook'),
#  Text(2, 0, 'eating_out'),
#  Text(3, 0, 'employment'),
#  Text(4, 0, 'ethnic_food'),
#  Text(5, 0, 'exercise'),
#  Text(6, 0, 'fruit_day'),
#  Text(7, 0, 'income'),
#  Text(8, 0, 'on_off_campus'),
#  Text(9, 0, 'pay_meal_out'),
#  Text(10, 0, 'sports'),
#  Text(11, 0, 'veggies_day')]
